# %% [markdown]
# # Ovo je test

# %%
print("test")
# Out:
# test

# %%
wn = [1, -2, 3, -4, 5 ]
# Out:
# 5-element Vector{Int64}:
#   1
#  -2
#   3
#  -4
#   5

# %%
sum = 0
for i in wn
    sum+=i
    print(sum," ")
end
# Out:
# 1 -1 2 -2 3
